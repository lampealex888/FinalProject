# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('value.csv', low_memory=False)

# Count the number of houses that have mortgages, contracts to purchase, or similar debts.
df['Estimate; Total: - Less than $10,000'] = df['Estimate; Total: - Less than $10,000'].apply(lambda x: x*5000)
less10_df = df.groupby(['Neighborhood'])['Estimate; Total: - Less than $10,000'].sum()

df['Estimate; Total: - $10,000 to $14,999'] = df['Estimate; Total: - $10,000 to $14,999'].apply(lambda x: x*12500)
more10less15_df = df.groupby(['Neighborhood'])['Estimate; Total: - $10,000 to $14,999'].sum()
horizontal_stack = pd.concat([less10_df, more10less15_df], axis=1)

df['Estimate; Total: - $15,000 to $19,999'] = df['Estimate; Total: - $15,000 to $19,999'].apply(lambda x: x*17500)
more15less20_df = df.groupby(['Neighborhood'])['Estimate; Total: - $15,000 to $19,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more15less20_df], axis=1)

df['Estimate; Total: - $20,000 to $24,999'] = df['Estimate; Total: - $20,000 to $24,999'].apply(lambda x: x*17500)
more20less25_df = df.groupby(['Neighborhood'])['Estimate; Total: - $20,000 to $24,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more20less25_df], axis=1)

df['Estimate; Total: - $20,000 to $24,999'] = df['Estimate; Total: - $20,000 to $24,999'].apply(lambda x: x*22500)
more20less25_df = df.groupby(['Neighborhood'])['Estimate; Total: - $20,000 to $24,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more20less25_df], axis=1)

df['Estimate; Total: - $25,000 to $29,999'] = df['Estimate; Total: - $25,000 to $29,999'].apply(lambda x: x*27500)
more25less30_df = df.groupby(['Neighborhood'])['Estimate; Total: - $25,000 to $29,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more25less30_df], axis=1)

df['Estimate; Total: - $30,000 to $34,999'] = df['Estimate; Total: - $30,000 to $34,999'].apply(lambda x: x*32500)
more30less35_df = df.groupby(['Neighborhood'])['Estimate; Total: - $30,000 to $34,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more30less35_df], axis=1)

df['Estimate; Total: - $35,000 to $39,999'] = df['Estimate; Total: - $35,000 to $39,999'].apply(lambda x: x*37500)
more35less40_df = df.groupby(['Neighborhood'])['Estimate; Total: - $35,000 to $39,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more35less40_df], axis=1)

df['Estimate; Total: - $40,000 to $49,999'] = df['Estimate; Total: - $40,000 to $49,999'].apply(lambda x: x*45000)
more40less50_df = df.groupby(['Neighborhood'])['Estimate; Total: - $40,000 to $49,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more40less50_df], axis=1)

df['Estimate; Total: - $50,000 to $59,999'] = df['Estimate; Total: - $50,000 to $59,999'].apply(lambda x: x*55000)
more50less60_df = df.groupby(['Neighborhood'])['Estimate; Total: - $50,000 to $59,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more50less60_df], axis=1)

df['Estimate; Total: - $60,000 to $69,999'] = df['Estimate; Total: - $60,000 to $69,999'].apply(lambda x: x*65000)
more60less70_df = df.groupby(['Neighborhood'])['Estimate; Total: - $60,000 to $69,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more60less70_df], axis=1)

df['Estimate; Total: - $70,000 to $79,999'] = df['Estimate; Total: - $70,000 to $79,999'].apply(lambda x: x*75000)
more70less80_df = df.groupby(['Neighborhood'])['Estimate; Total: - $70,000 to $79,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more70less80_df], axis=1)

df['Estimate; Total: - $80,000 to $89,999'] = df['Estimate; Total: - $80,000 to $89,999'].apply(lambda x: x*85000)
more80less90_df = df.groupby(['Neighborhood'])['Estimate; Total: - $80,000 to $89,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more80less90_df], axis=1)

df['Estimate; Total: - $90,000 to $99,999'] = df['Estimate; Total: - $90,000 to $99,999'].apply(lambda x: x*95000)
more90less100_df = df.groupby(['Neighborhood'])['Estimate; Total: - $90,000 to $99,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more90less100_df], axis=1)

df['Estimate; Total: - $100,000 to $124,999'] = df['Estimate; Total: - $100,000 to $124,999'].apply(lambda x: x*115000)
more100less125_df = df.groupby(['Neighborhood'])['Estimate; Total: - $100,000 to $124,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more100less125_df], axis=1)

df['Estimate; Total: - $125,000 to $149,999'] = df['Estimate; Total: - $125,000 to $149,999'].apply(lambda x: x*137500)
more125less150_df = df.groupby(['Neighborhood'])['Estimate; Total: - $125,000 to $149,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more125less150_df], axis=1)

df['Estimate; Total: - $150,000 to $174,999'] = df['Estimate; Total: - $150,000 to $174,999'].apply(lambda x: x*167500)
more150less175_df = df.groupby(['Neighborhood'])['Estimate; Total: - $150,000 to $174,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more150less175_df], axis=1)

df['Estimate; Total: - $175,000 to $199,999'] = df['Estimate; Total: - $175,000 to $199,999'].apply(lambda x: x*187500)
more175less200_df = df.groupby(['Neighborhood'])['Estimate; Total: - $175,000 to $199,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more175less200_df], axis=1)

df['Estimate; Total: - $200,000 to $249,999'] = df['Estimate; Total: - $200,000 to $249,999'].apply(lambda x: x*225000)
more200less250_df = df.groupby(['Neighborhood'])['Estimate; Total: - $200,000 to $249,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more200less250_df], axis=1)

df['Estimate; Total: - $250,000 to $299,999'] = df['Estimate; Total: - $250,000 to $299,999'].apply(lambda x: x*275000)
more250less300_df = df.groupby(['Neighborhood'])['Estimate; Total: - $250,000 to $299,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more250less300_df], axis=1)

df['Estimate; Total: - $300,000 to $399,999'] = df['Estimate; Total: - $300,000 to $399,999'].apply(lambda x: x*350000)
more300less400_df = df.groupby(['Neighborhood'])['Estimate; Total: - $300,000 to $399,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more300less400_df], axis=1)

df['Estimate; Total: - $400,000 to $499,999'] = df['Estimate; Total: - $400,000 to $499,999'].apply(lambda x: x*450000)
more400less500_df = df.groupby(['Neighborhood'])['Estimate; Total: - $400,000 to $499,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more400less500_df], axis=1)

df['Estimate; Total: - $500,000 to $749,999'] = df['Estimate; Total: - $500,000 to $749,999'].apply(lambda x: x*625000)
more500less750_df = df.groupby(['Neighborhood'])['Estimate; Total: - $500,000 to $749,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more500less750_df], axis=1)

df['Estimate; Total: - $750,000 to $999,999'] = df['Estimate; Total: - $750,000 to $999,999'].apply(lambda x: x*875000)
more750less1000_df = df.groupby(['Neighborhood'])['Estimate; Total: - $750,000 to $999,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more750less1000_df], axis=1)

df['Estimate; Total: - $1,000,000 to $1,499,999'] = df['Estimate; Total: - $1,000,000 to $1,499,999'].apply(lambda x: x*1250000)
more1000less1500_df = df.groupby(['Neighborhood'])['Estimate; Total: - $1,000,000 to $1,499,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more1000less1500_df], axis=1)

df['Estimate; Total: - $1,500,000 to $1,999,999'] = df['Estimate; Total: - $1,500,000 to $1,999,999'].apply(lambda x: x*1750000)
more1500less2000_df = df.groupby(['Neighborhood'])['Estimate; Total: - $1,500,000 to $1,999,999'].sum()
horizontal_stack = pd.concat([horizontal_stack, more1500less2000_df], axis=1)

df['Estimate; Total: - $2,000,000 or more'] = df['Estimate; Total: - $2,000,000 or more'].apply(lambda x: x*2000000)
morethan2000_df = df.groupby(['Neighborhood'])['Estimate; Total: - $2,000,000 or more'].sum()
horizontal_stack = pd.concat([horizontal_stack, morethan2000_df], axis=1)
# df['Margin of Error; Total: - $20,000 to $24,999'] = df['Margin of Error; Total: - $20,000 to $24,999'].apply(lambda x: x*20000)
# less10_df = df.groupby(['Neighborhood'])['Estimate; Total: - Less than $10,000'].sum()


#print(new_df)

# Show the 5 neighborhoods with the most debt by number of houses.
horizontal_stack['sum'] = horizontal_stack.sum(axis=1)
total = df.groupby(['Neighborhood'])['Estimate; Total:'].sum()
new_df = pd.concat([horizontal_stack, total], axis=1)
new_df['average'] = new_df['sum'] / new_df['Estimate; Total:']
new_df = new_df.nlargest(5, columns='average')
new_df.head(5)

#new_df.nlargest(5, columns='average').plot(y='average', kind='bar')
# Plot the 5 neighborhoods with the most debt by number of houses.
#new_df.nlargest(5, columns='mean').plot(y='mean',kind="bar")
# Out:
#                    Estimate; Total: - Less than $10,000  \
# Neighborhood
# West End                                            0.0
# Bedford Dwellings                               20000.0
# Esplen                                              0.0
# Spring Garden                                   20000.0
# Beltzhoover                                     20000.0
#
#                    Estimate; Total: - $10,000 to $14,999  \
# Neighborhood
# West End                                             0.0
# Bedford Dwellings                                62500.0
# Esplen                                               0.0
# Spring Garden                                   150000.0
# Beltzhoover                                     237500.0
#
#                    Estimate; Total: - $15,000 to $19,999  \
# Neighborhood
# West End                                             0.0
# Bedford Dwellings                               140000.0
# Esplen                                               0.0
# ...
